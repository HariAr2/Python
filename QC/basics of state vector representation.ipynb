# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2,2)
qc.draw()

# %%
from qiskit.quantum_info import Statevector
 
psi = Statevector.from_label('1')
print(psi)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
qc.measure_all()
qc.draw()

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram

# Define the quantum circuit
qc = QuantumCircuit(2)
state = Statevector.from_instruction(qc)

# Plot the histogram
plot_histogram(state.probabilities_dict())

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
qc=QuantumCircuit(2,2)
psi = Statevector([0.57735027+0.j, 0.816496+0.j])
print(psi)
# Out:
# Statevector([0.57735027+0.j, 0.816496  +0.j],
#             dims=(2,))

# %%
qc.initialize(psi.data, 0)

# Get the statevector of the quantum circuit
state = Statevector.from_instruction(qc)

# Plot the histogram
plot_histogram(state.probabilities_dict())
